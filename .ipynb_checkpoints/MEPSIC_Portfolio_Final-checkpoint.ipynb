# %% [markdown]
# ## U.S. Employer Health Insurance: An Exploratory Data Analysis using MEPS-IC Survey Data
#
# ## Background
#
# This project uses data from the **Medical Expenditure Panel Survey – Insurance Component (MEPS-IC)**, published by the Agency for Healthcare Research and Quality (AHRQ).
#
# It's an annual survey that goes back to 1996 and collects data directly from private-sector employers on things like how much they spend on health insurance, what plans they offer, and how many employees actually enroll. I chose to focus only on the private sector data.
#
# **Source:** [https://datatools.ahrq.gov/meps-ic/](https://datatools.ahrq.gov/meps-ic/)
#
# ---
#
# ## Why I chose this dataset
#
# As part of the Financial, Actuarial and Analytics team at WTW, I spend most of my time analyzing cost and utilisation trends to help clients make decisions about their benefits strategy. A big part of that work is benchmarking, helping clients understand whether what they're spending is reasonable for their size and industry. But since I work in a GDC (Global Delivery Centre), this data mostly sits with the consulting teams who directly deal with clients. To understand the broader context my work feeds into, I looked for a public dataset that covers similar ground. The MEPS-IC survey made sense since it tracks the same things I work with day to day (enrollment, premiums, employer contributions, etc.) but just at a national level.
#
# ---
#
# ## Questions I want to answer
#
# 1. How have average health insurance premiums changed over time?
# 2. Does firm size affect how much employees pay?
# 3. Which industries have the highest premiums?
# 4. How is the premium split between employer and employee?
# 5. How have employee enrollment rates changed over time?

# %% [markdown]
# ## Loading the Data

# %%
# Importing libraries I will need
import pandas as pd
import matplotlib.pyplot as plt
from sqlalchemy import create_engine

# %%
# Loading the cleaned Excel file into a dataframe
df = pd.read_excel("MEPSIC_Survey_Data.xlsx")
print("Data loaded successfully.")
# Out:
# Data loaded successfully.

# %%
# Performing a quick check
print("Total rows:", len(df))
print("Total columns:", len(df.columns))
df.head()
# Out:
# Total rows: 619700
# Total columns: 19
#     sector  coverage  year                      dashboard_name table_no  \
# 0  Private  National  2023  Premiums/Contributions/Enrollments    I.C.5
# 1  Private  National  2023  Premiums/Contributions/Enrollments    I.C.5
# 2  Private  National  2023  Premiums/Contributions/Enrollments    I.C.5
# 3  Private  National  2023  Premiums/Contributions/Enrollments    I.C.5
# 4  Private  National  2023  Premiums/Contributions/Enrollments    I.C.5
#
#                                             estimate  \
# 0  Percent of employees enrolled in a health insu...
# 1  Percent of employees enrolled in a health insu...
# 2  Percent of employees enrolled in a health insu...
# 3  Percent of employees enrolled in a health insu...
# 4  Percent of employees enrolled in a health insu...
#
#                 estimate_category estimate_subcategory  \
# 0  Single coverage Purchased plan                  NaN
# 1  Single coverage Purchased plan                  NaN
# 2  Single coverage Purchased plan                  NaN
# 3  Single coverage Purchased plan                  NaN
# 4  Single coverage Purchased plan                  NaN
#
#                                    table_description       row_group  \
# 0  Percent of private-sector employees enrolled i...     Age of firm
# 1  Percent of private-sector employees enrolled i...  Union presence
# 2  Percent of private-sector employees enrolled i...     Age of firm
# 3  Percent of private-sector employees enrolled i...     Age of firm
# 4  Percent of private-sector employees enrolled i...     Age of firm
#
#              row_label  col_group               col_label percent     value  \
# 0    Less than 5 years  Firm size  1000 or more employees     YES       NaN
# 1  Has union employees  Firm size  Less than 10 employees     YES       NaN
# 2     20 or more years  Firm size  Less than 50 employees     YES  0.656935
# 3            5-9 years  Firm size  Less than 50 employees     YES  0.675934
# 4          10-19 years  Firm size                   Total     YES  0.639902
#
#    value_rounded   std_err  std_err_rounded reliability_indicator
# 0            NaN       NaN              NaN                   NaN
# 1            NaN       NaN              NaN                   NaN
# 2           65.7  0.010589             1.06                   NaN
# 3           67.6  0.022286             2.23                   NaN
# 4           64.0  0.010426             1.04                   NaN

# %% [markdown]
# ## Exploring the Data

# %% [markdown]
# Before I write any queries, I want to understand what fields we have and the values contained within them. The MEPS-IC data isn't structured like a typical table, but instead, organized in a long-format table of different estimates with different groupings.

# %%
# Checking columns and data types
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 619700 entries, 0 to 619699
# Data columns (total 19 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   sector                 619700 non-null  str
#  1   coverage               619700 non-null  str
#  2   year                   619700 non-null  int64
#  3   dashboard_name         619700 non-null  str
#  4   table_no               619700 non-null  str
#  5   estimate               619700 non-null  str
#  6   estimate_category      504466 non-null  str
#  7   estimate_subcategory   112976 non-null  str
#  8   table_description      619700 non-null  str
#  9   row_group              599973 non-null  str
#  10  row_label              619700 non-null  str
#  11  col_group              619700 non-null  str
#  12  col_label              619700 non-null  str
#  13  percent                619700 non-null  str
#  14  value                  574869 non-null  float64
#  15  value_rounded          574869 non-null  float64
#  16  std_err                574870 non-null  float64
#  17  std_err_rounded        574870 non-null  float64
#  18  reliability_indicator  39400 non-null   str
# dtypes: float64(4), int64(1), str(14)
# memory usage: 89.8 MB

# %%
# Loading the data schema to check what data each column represents
schema_df = pd.read_excel("MEPSIC_Survey_Data_Schema.xlsx")
pd.set_option('display.max_colwidth', None)
display(schema_df)
# Out:
#               Column Name  \
# 0                  sector
# 1                coverage
# 2                    year
# 3          dashboard_name
# 4                table_no
# 5                estimate
# 6       estimate_category
# 7    estimate_subcategory
# 8       table_description
# 9               row_group
# 10              row_label
# 11              col_group
# 12              col_label
# 13                percent
# 14                  value
# 15          value_rounded
# 16                std_err
# 17        std_err_rounded
# 18  reliability_indicator
#
#                                                                                                                                                                                                                                                                                                           Description
# 0                                                                                                                                                                                                                         The sector of the economy the data covers. Other exports cover Public and Civilian sectors.
# 1                                                                                                                                                                                                                 The type of health insurance coverage tier. Determines which premium/cost figures apply to the row.
# 2                                                                                                                                                                                                                             Survey reference year. Note: 2007 is missing due to a change in how data was collected.
# 3                                                                                                                                                                       The name of the dashboard panel (tab) the row came from. Corresponds to one of the five thematic dashboard sections in the MEPS-IC Data Tool.
# 4   Hierarchical MEPS-IC table identifier. The letter prefix indicates the broad topic area (e.g. A = Establishment-level, B = Employee-level, C–E = Premiums by coverage type, F = Deductibles and copayments, G = Percentile distributions), with numbers and sub-letters narrowing to a specific cross-tabulation.
# 5                                                                                                                                                                            A short code identifying the specific metric reported in the row. Together with table_no, it uniquely identifies what is being measured.
# 6                                                                                                                                             The primary stratification dimension applied to the estimate; the characteristic by which results are broken out (the 'rows' of the original MEPS-IC published tables).
# 7                                                                                                                                                                                     The specific value or stratum within estimate_category that applies to this row, i.e., the cell label from the published table.
# 8                                                                                                                                                                                   The title of the original MEPS-IC published table this row's data comes from, the clearest description of what is being measured.
# 9                                                                                                                                                                                   Groups of rows within a table. Used when the published table has multiple labelled sections (e.g. 'By Firm Size', 'By Industry').
# 10                                                                                                                                                                                         Describes what population or stratum the estimate covers. It is the most granular label for the row, suitable for display.
# 11                                                                            Groups of columns within a table. Used when the published table has multiple column sections (e.g. 'Estimate' and 'Standard Error' sections, or breakdowns by plan type). Corresponds to the column-group header in the original table.
# 12                                                                                                                                                                                     Identifies what the value in this row represents at the column level, often a plan type, a cost component, or a coverage tier.
# 13                                                                                                                                                                         Indicates whether the value and std_err columns contain a percentage estimate (True/1) or a dollar-denominated / count estimate (False/0).
# 14                                                                                          The point estimate for this row. Units vary by measure type: percentage points for rates like offer or take-up, annual US dollars for premiums and contributions, and whole numbers for counts like total establishments.
# 15                                                                                                                                                        Rounded version of value. Rounding conventions: percentages to one decimal place; dollar amounts to the nearest dollar; counts to the nearest whole number.
# 16                                                                                                                                        Standard error of the point estimate; a measure of how precise the estimate is given the survey's sample size. Used to assess reliability and compute confidence intervals.
# 17                                                                                                                                                                      Rounded version of std_err, matching the precision published in official MEPS-IC standard error tables. Same rounding rules as value_rounded.
# 18                                                                                                                                                                 A data quality flag showing whether AHRQ considers the estimate reliable enough to publish. Suppressed estimates should be excluded from analysis.

# %%
# Filtering the schema to only show columns relevant to our analysis
columns_we_use = ['year', 'estimate', 'estimate_category', 'row_group','row_label', 'col_group', 'col_label', 'value_rounded']
filtered_schema = schema_df[schema_df['Column Name'].isin(columns_we_use)]
display(filtered_schema[['Column Name', 'Description']])
# Out:
#           Column Name  \
# 2                year
# 5            estimate
# 6   estimate_category
# 9           row_group
# 10          row_label
# 11          col_group
# 12          col_label
# 15      value_rounded
#
#                                                                                                                                                                                                                                 Description
# 2                                                                                                                                                   Survey reference year. Note: 2007 is missing due to a change in how data was collected.
# 5                                                                                                  A short code identifying the specific metric reported in the row. Together with table_no, it uniquely identifies what is being measured.
# 6                                                                   The primary stratification dimension applied to the estimate; the characteristic by which results are broken out (the 'rows' of the original MEPS-IC published tables).
# 9                                                                                                         Groups of rows within a table. Used when the published table has multiple labelled sections (e.g. 'By Firm Size', 'By Industry').
# 10                                                                                                               Describes what population or stratum the estimate covers. It is the most granular label for the row, suitable for display.
# 11  Groups of columns within a table. Used when the published table has multiple column sections (e.g. 'Estimate' and 'Standard Error' sections, or breakdowns by plan type). Corresponds to the column-group header in the original table.
# 12                                                                                                           Identifies what the value in this row represents at the column level, often a plan type, a cost component, or a coverage tier.
# 15                                                                              Rounded version of value. Rounding conventions: percentages to one decimal place; dollar amounts to the nearest dollar; counts to the nearest whole number.

# %%
# The estimate column is our key field - capping at 25 since there are a lot of unique values
df['estimate'].value_counts().head(25)
# Out:
# estimate
# Average total premium per enrolled employee at establishments that offer health insurance                                     64056
# Average total employee contribution per enrolled employee at establishments that offer health insurance                       64024
# Percent of total premiums contributed by employees enrolled at establishments that offer health insurance                     64024
# Percent of employees enrolled in a health insurance plan                                                                      21088
# Number of employees                                                                                                           20712
# Percent of employees in establishments that offer health insurance                                                            20696
# Percent of employees eligible for health insurance at establishments that offer health insurance                              20688
# Percent of employees eligible and enrolled in health insurance at establishments that offer health insurance                  20688
# Percent of employees enrolled in health insurance at establishments that offer health insurance                               20688
# Percent of employees enrolled in a health insurance plan that required no employee contribution                               19400
# Percent of number of employees                                                                                                18123
# Number of private-sector establishments                                                                                        6912
# Percent of private-sector establishments by whether they offer health insurance                                                6912
# Percent of establishments that offer at least one plan for single coverage with no required employee contribution              6896
# Percent of establishments that offer an any-provider plan for single coverage with no required employee contribution           6896
# Percent of establishments that offer at least one plan for family coverage with no required employee contribution              6896
# Percent of establishments that offer health insurance that offer two or more health insurance plans                            6888
# Percent of establishments that offer an exclusive-provider plan for single coverage with no required employee contribution     6888
# Percent of establishments that offer an any-provider plan for family coverage with no required employee contribution           6888
# Percent of establishments that offer an exclusive-provider plan for family coverage with no required employee contribution     6888
# Percent of employees working in establishments that offer two or more health insurance plans                                   6888
# Percent of establishments that offer a mixed-provider plan for single coverage with no required employee contribution          6880
# Percent of establishments that offer a mixed-provider plan for family coverage with no required employee contribution          6880
# Percent of enrollees enrolled in self-insured plans at establishments that offer health insurance                              6880
# Percent of number of private-sector establishments                                                                             6048
# Name: count, dtype: int64

# %%
# Checking what estimate_category, estimate_subcategory, and row_group look like
display("estimate_category values:")
display(df['estimate_category'].unique())
print()
display("estimate_subcategory values:")
display(df['estimate_subcategory'].unique())
print()
display("row_group values:")
display(df['row_group'].unique())
# Out:
# 'estimate_category values:'
# <StringArray>
# [               'Single coverage Purchased plan',
#        'Single coverage Exclusive-provider plan',
#                                'Family coverage',
#            'Single coverage Mixed-provider plan',
#                                'Single coverage',
#              'Single coverage Any-provider plan',
#                 'Family coverage Purchased plan',
#                     'Employee-plus-one coverage',
#      'Employee-plus-one coverage Purchased plan',
#                                'National totals',
#              'Family coverage Self-insured plan',
#        'Family coverage Exclusive-provider plan',
#              'Single coverage Self-insured plan',
#              'Family coverage Any-provider plan',
#            'Family coverage Mixed-provider plan',
#  'Employee-plus-one coverage  Self-insured plan',
#                           'Overall Cost Sharing',
#                             'Prescription Drugs',
#                                      'Plan Type',
#                               'Physician Visits',
#                            'Hospital Admissions',
#                      'Out-of-Network Deductible',
#                                              nan,
#                                  'All employees',
#                            'Part-time employees',
#                            'Full-time employees']
# Length: 26, dtype: str
# 'estimate_subcategory values:'
# <StringArray>
# [                                                         nan,
#                                                  'Deductible',
#                                       'Maximum out-of-pocket',
#         'High Deductible Health Plan (HDHP): Single Coverage',
#         'High Deductible Health Plan (HDHP): Family Coverage',
#                                                 'Coinsurance',
#                                                   'Copayment',
#  'Non-High Deductible Health Plan (non-HDP): Family Coverage',
#  'Non-High Deductible Health Plan (non-HDP): Single Coverage',
#                                                       'Copay',
#                                         'Out-of-Network Care']
# Length: 11, dtype: str
# 'row_group values:'
# <StringArray>
# [                                                                  'Age of firm',
#                                                                 'Union presence',
#                                                        'Percent women employees',
#                                                                 'Industry group',
#                                                            'Multi/single status',
#                                                                              nan,
#                                                                      'Ownership',
#                                              'Percent age 50 or older employees',
#                                                    'Percent full-time employees',
#                                                     'Percent low-wage employees',
#                                                                'Purchased Plans',
#                                                             'Self-insured Plans',
#                                              'Agriculture, fishing, or forestry',
#                                                                   'Construction',
#                                              'Financial services or real estate',
#                                                        'Mining or manufacturing',
#                                                                 'Other services',
#                                                          'Professional services',
#                                                                   'Retail trade',
#                                                    'Utilities or transportation',
#                                                                'Wholesale trade',
#                            'Agriculture, fishing, or forestry - Purchased Plans',
#                         'Agriculture, fishing, or forestry - Self-insured Plans',
#                                                 'Construction - Purchased Plans',
#                                              'Construction - Self-insured Plans',
#                            'Financial services or real estate - Purchased Plans',
#                         'Financial services or real estate - Self-insured Plans',
#                                      'Mining or manufacturing - Purchased Plans',
#                                   'Mining or manufacturing - Self-insured Plans',
#                                               'Other services - Purchased Plans',
#                                            'Other services - Self-insured Plans',
#                                        'Professional services - Purchased Plans',
#                                     'Professional services - Self-insured Plans',
#                                                 'Retail trade - Purchased Plans',
#                                              'Retail trade - Self-insured Plans',
#                                  'Utilities or transportation - Purchased Plans',
#                               'Utilities or transportation - Self-insured Plans',
#                                              'Wholesale trade - Purchased Plans',
#                                           'Wholesale trade - Self-insured Plans',
#                                     'Retail trade - Purchased Plans (1996-2000)',
#                                                             'Mining (1996-1999)',
#                                                      'Manufacturing (1996-1999)',
#                                   'Transportation, communications, or utilities',
#                              'Ag/forestry/fishing - Purchased Plans (1996-2000)',
#                                  'Retail trade - Self-insured Plans (1996-2000)',
#                                  'Construction - Self-insured Plans (1996-2000)',
#                                     'Construction - Purchased Plans (1996-2000)',
#                            'Ag/forestry/fishing - Self-insured Plans(1996-2000)',
#               'Finance, insurance, or real estate - Purchased Plans (1996-2000)',
#       'Services (personal, business, or other) - Self-insured Plans (1996-2000)',
#          'Services (personal, business, or other) - Purchased Plans (1996-2000)',
#     'Transportation, communications, or utilities - Purchased Plans (1996-2000)',
#  'Transportation, communications, or utilities - Self-insured Plans (1996-2000)',
#                                           'Mining - Purchased Plans (1996-2000)',
#                                 'Manufacturing - Self-insured Plans (1996-2000)',
#                                    'Manufacturing - Purchased Plans (1996-2000)',
#                                        'Mining - Self-insured Plans (1996-2000)',
#            'Finance, insurance, or real estate - Self-insured Plans (1996-2000)',
#                                          'Unknown - Purchased Plans (1996-2000)',
#                                       'Unknown - Self-insured Plans (1996-2000)',
#                                         'Services (personal, business or other)',
#                                                                        'Unknown',
#                                                                      'Firm size',
#                                                                'Family coverage',
#                                                     'Employee-plus-one coverage',
#                                                                'Single coverage']
# Length: 66, dtype: str

# %%
# Also checking col_group and col_label
display("col_group values:")
display(df['col_group'].unique())
print()
display("col_label values:")
display(df['col_label'].unique())
# Out:
# 'col_group values:'
# <StringArray>
# [                           'Firm size',
#                                 'Total',
#               'Prescription drug copay',
#                        'Benefits plans',
#              'Plan provider arrangment',
#          'Insurance offers to retirees',
#                         'Plan coverage',
#  'Plans offered through a Union or AHP']
# Length: 8, dtype: str
# 'col_label values:'
# <StringArray>
# [         '1000 or more employees',          'Less than 10 employees',
#           'Less than 50 employees',                           'Total',
#                  '10-24 employees',               '100-999 employees',
#                  '25-99 employees',            '50 or more employees',
#   'Total (in millions of dollars)', 'Total (in thousands of persons)',
#                          'Generic',                   'Non-Preferred',
#                        'Specialty',                       'Preferred',
#             'Pretax Contributions',         'Flexible Benefits Plans',
#                  '25-49 employees',                '50-100 employees',
#        'Flexible Spending Account',          'Conventional indemnity',
#                 'Any managed care',                  'Mixed provider',
#                '100-499 employees',           '500 or more employees',
#          'Less than 100 employees',   'Insurance to retirees over 65',
#   'Insurance to retirees under 65',              'Exclusive provider',
#                     'Adult Dental',                    'Child Dental',
#               'Mental Health Care',       'Substance Abuse Treatment',
#                              'AHP',           'Neither Union nor AHP',
#                            'Union']
# Length: 35, dtype: str

# %%
# Checking for any null or duplicate values
display("Null counts per column:")
display(df.isnull().sum())
print()
display("Duplicate rows:")
display(df.duplicated().sum(), "duplicate rows found")
print()
display("Value range for value_rounded:")
display(df['value_rounded'].describe())
# Out:
# 'Null counts per column:'
# sector                        0
# coverage                      0
# year                          0
# dashboard_name                0
# table_no                      0
# estimate                      0
# estimate_category        115234
# estimate_subcategory     506724
# table_description             0
# row_group                 19727
# row_label                     0
# col_group                     0
# col_label                     0
# percent                       0
# value                     44831
# value_rounded             44831
# std_err                   44830
# std_err_rounded           44830
# reliability_indicator    580300
# dtype: int64
# 'Duplicate rows:'
# np.int64(0)
# 'duplicate rows found'
# 'Value range for value_rounded:'
# count    5.748690e+05
# mean     3.048387e+05
# std      3.260730e+06
# min      0.000000e+00
# 25%      2.200000e+01
# 50%      5.990000e+01
# 75%      1.664000e+03
# max      1.394411e+08
# Name: value_rounded, dtype: float64

# %%
# Loading the dataframe into an in-memory SQLite database so I can run queries directly inside the notebook.
engine = create_engine("sqlite:///:memory:")
df.to_sql("meps_ic", con=engine, index=False, if_exists="replace")

print("Database is ready.")
# Out:
# Database is ready.

# %%
# Adding a helper function to avoid redundancy
def run_query(sql):
    return pd.read_sql_query(sql, con=engine)

# %% [markdown]
# ---
#
# ## Question 1: How have average single premiums changed over time?
#
# Health insurance costs have been rising for years, but by how much exactly? I want to see the national average single coverage premium for each year available in the dataset.

# %%
# Note: I had to use 'LIKE' instead of '=' for the estimate column because the strings have some extra text in them and an exact match returns nothing.
query = """
SELECT 
    year,
    CAST(ROUND(AVG(value_rounded), 0) AS INTEGER) AS avg_single_premium
FROM meps_ic
WHERE estimate LIKE '%Average total premium%'
  AND estimate_category = 'Single coverage'
  AND col_label = 'Total'
GROUP BY year
ORDER BY year
"""
premium_trend = run_query(query)
display(premium_trend)
# Out:
#     year  avg_single_premium
# 0   1996                2027
# 1   1997                2057
# 2   1998                2202
# 3   1999                2320
# 4   2000                2675
# 5   2001                2877
# 6   2002                3154
# 7   2003                3451
# 8   2004                3654
# 9   2005                3972
# 10  2006                4091
# 11  2008                4333
# 12  2009                4578
# 13  2010                4876
# 14  2011                5143
# 15  2012                5290
# 16  2013                5442
# 17  2014                5774
# 18  2015                5824
# 19  2016                5954
# 20  2017                6234
# 21  2018                6634
# 22  2019                6943
# 23  2020                7053
# 24  2021                7311
# 25  2022                7478
# 26  2023                8076
# 27  2024                8379

# %%
# Plotting a line chart to see the overall trend
plt.figure(figsize=(10, 5))
plt.plot(premium_trend['year'], premium_trend['avg_single_premium'], marker='o', color='#003f5c', linewidth=2)
plt.title('Average Single Health Insurance Premium Over Time')
plt.ylabel('Average Premium ($)')
plt.xlabel('Year')
plt.tight_layout()
plt.show()

# %% [markdown]
# **What I found:** The rise is pretty striking when you see it laid out like this. Premiums have gone up roughly 4x from 1996 to now, and there's no real dip, even during the 2008 recession it just keeps going up. This graph highlights why benchmarking is important; if premiums are rising faster than the national trend, it's worth looking into.

# %% [markdown]
# ---
#
# ## Question 2: Does company size affect how much employees pay in premiums?
#
# My assumption going into this was that larger companies pay less because they have more bargaining power with insurers. I want to check if that's actually true for 2024.

# %%
query = """
SELECT 
    col_label AS firm_size,
    CAST(ROUND(AVG(value_rounded), 0) AS INTEGER) AS avg_premium
FROM meps_ic
WHERE year = 2024
  AND estimate LIKE '%Average total premium%'
  AND estimate_category = 'Single coverage'
  AND col_label NOT IN ('Total', 'Less than 50 employees', '50 or more employees')
GROUP BY col_label
ORDER BY avg_premium DESC
"""
firm_size = run_query(query)
display(firm_size)
# Out:
#                 firm_size  avg_premium
# 0  Less than 10 employees         8774
# 1  1000 or more employees         8465
# 2         10-24 employees         8413
# 3       100-999 employees         8228
# 4         25-99 employees         8065

# %%
# The query returns results sorted by premium (highest to lowest) but I want the bar chart sorted by firm size (smallest to largest)
size_order = ['Less than 10 employees', '10-24 employees',
              '25-99 employees', '100-999 employees', '1000 or more employees']
firm_size['firm_size'] = pd.Categorical(firm_size['firm_size'], categories=size_order, ordered=True)
firm_size = firm_size.sort_values('firm_size')

plt.figure(figsize=(10, 5))
plt.bar(firm_size['firm_size'], firm_size['avg_premium'], color='#003f5c')
plt.title('Average Single Premium by Firm Size (2024)')
plt.ylabel('Average Premium ($)')
plt.xlabel('Firm Size')
plt.tight_layout()
plt.show()

# %% [markdown]
# **What I found:** Interestingly, my assumptions did not hold as well as I had expected. The smallest firms do pay the highest average premium, but the gap between them and the largest firms is surprisingly small. I thought there'd be a much steeper drop as firm size grew.
#
# One possible explanation: large firms tend to offer richer plan designs, which keeps their total premium high even if they negotiate a better rate. This is something that has come up repeatedly in conversations with our consultants, based on feedback they’ve gathered while working closely with clients.

# %% [markdown]
# ---
#
# ## Question 3: Which industries have the highest premiums?
#
# Now I'm curious whether industry matters more than firm size. Some sectors might have older workforces, or just offer more generous benefits overall. Let me rank all the industries by their average single premium in 2024.

# %%
query = """
SELECT 
    row_label AS industry,
    CAST(ROUND(AVG(value_rounded), 0) AS INTEGER) AS avg_premium
FROM meps_ic
WHERE year = 2024
  AND estimate LIKE '%Average total premium%'
  AND estimate_category = 'Single coverage'
  AND row_group = 'Industry group'
  AND col_label = 'Total'
GROUP BY row_label
ORDER BY avg_premium DESC
"""
by_industry = run_query(query)
display(by_industry)
# Out:
#                        industry  avg_premium
# 0         Professional services         8963
# 1                Other services         8825
# 2       Fin. svs. and real est.         8764
# 3               Wholesale trade         8513
# 4  Utilities and transportation         8208
# 5      Mining and manufacturing         8057
# 6           Ag/forestry/fishing         7828
# 7                  Retail trade         7709
# 8                  Construction         7109

# %%
# Plotting a horizontal bar chart so the industry labels don't get cut off
plt.figure(figsize=(10, 6))
plt.barh(by_industry['industry'][::-1], by_industry['avg_premium'][::-1], color='#003f5c')
plt.title('Average Single Premium by Industry (2024)')
plt.xlabel('Average Premium ($)')
plt.tight_layout()
plt.show()

# %% [markdown]
# **What I found:** I expected Construction or Mining to top this list since those are high-risk industries, but instead, it's Professional Services and Finance/Insurance at the top. Although it makes sense since those industries compete hard on compensation and benefits to attract talent, so they offer richer plans. Agriculture and Construction being at the bottom also makes sense given how many workers in that sector are seasonal or work through subcontractors, so they may not be on employer plans at all.

# %% [markdown]
# ---
#
# ## Question 4: How is the premium split between employer and employee?
#
# Looking at the total premium is useful but I want to know who's actually paying it. Does the employer absorb more in larger firms? Let me compare the employer vs. employee share by firm size for 2024.

# %%
# Calculating total premium and employee contribution
query = """
WITH total AS (
    SELECT 
        col_label AS firm_size,
        CAST(ROUND(AVG(value_rounded), 0) AS INTEGER) AS total_premium
    FROM meps_ic
    WHERE year = 2024
      AND estimate LIKE '%Average total premium%'
      AND estimate_category = 'Single coverage'
      AND col_label NOT IN ('Total', 'Less than 50 employees', '50 or more employees')
    GROUP BY col_label
),
contrib AS (
    SELECT 
        col_label AS firm_size,
        CAST(ROUND(AVG(value_rounded), 0) AS INTEGER) AS employee_contribution
    FROM meps_ic
    WHERE year = 2024
      AND estimate LIKE '%Average total employee contribution%'
      AND estimate_category = 'Single coverage'
      AND col_label NOT IN ('Total', 'Less than 50 employees', '50 or more employees')
    GROUP BY col_label
)
SELECT
    t.firm_size,
    t.total_premium,
    c.employee_contribution,
    t.total_premium - c.employee_contribution AS employer_contribution,
    ROUND(100.0 * c.employee_contribution / t.total_premium, 1) AS employee_pct,
    ROUND(100.0 * (t.total_premium - c.employee_contribution) / t.total_premium, 1) AS employer_pct
FROM total t
JOIN contrib c ON t.firm_size = c.firm_size
"""
split = run_query(query)
display(split)
# Out:
#                 firm_size  total_premium  employee_contribution  \
# 0         10-24 employees           8413                   1988
# 1       100-999 employees           8228                   1790
# 2  1000 or more employees           8465                   1761
# 3         25-99 employees           8065                   1663
# 4  Less than 10 employees           8774                   1496
#
#    employer_contribution  employee_pct  employer_pct
# 0                   6425          23.6          76.4
# 1                   6438          21.8          78.2
# 2                   6704          20.8          79.2
# 3                   6402          20.6          79.4
# 4                   7278          17.1          82.9

# %%
# Sorting by firm size
split['firm_size'] = pd.Categorical(split['firm_size'], categories=size_order, ordered=True)
split = split.sort_values('firm_size').reset_index(drop=True)

#Using subplots for text labels
fig, ax = plt.subplots(figsize=(12, 5))
bars_employer = ax.bar(split['firm_size'], split['employer_contribution'], label='Employer pays', color='#003f5c', width=0.8)
bars_employee = ax.bar(split['firm_size'], split['employee_contribution'], bottom=split['employer_contribution'], label='Employee pays', color='#006770', width=0.8)

# Using loop to add percentage labels
for idx, row in split.iterrows():
    ax.text(idx, row['employer_contribution'] / 2,
            f"{row['employer_pct']}%", ha='center', va='center', color='white', fontsize=10)
    ax.text(idx, row['employer_contribution'] + row['employee_contribution'] / 2,
            f"{row['employee_pct']}%", ha='center', va='center', color='white', fontsize=10)

ax.set_title('Premium Split: Employer vs Employee by Firm Size (2024)')
ax.set_ylabel('Premium ($)')
ax.set_ylim(0, 10000)
ax.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# **What I found:** As expected, employers consistently absorb the larger share of the premium across all firm sizes. What's interesting though is that smaller firms are paying the most in absolute dollar terms, which means they're getting hit twice: higher total premiums and a bigger contribution out of pocket.

# %% [markdown]
# ---
#
# ## Question 5: How have employee enrollment rates changed over time?
#
# Just because a company offers health insurance doesn't mean everyone signs up. I want to look at what percentage of employees actually enroll, and whether that's changed over time. Rather than looking at all industries at once, I'll focus on the top 5 by enrollment rate.

# %%
# Using LIMIT 6 because 'Unknown' appears in the top results and is filtered out below
query_top5 = """
SELECT 
    row_label AS industry,
    ROUND(AVG(value_rounded), 1) AS avg_enrollment
FROM meps_ic
WHERE estimate LIKE '%Percent of employees enrolled%'
  AND row_group = 'Industry group'
  and row_label != 'Unknown'
  AND col_label = 'Total'
  AND year >= 2000
GROUP BY row_label
ORDER BY avg_enrollment DESC
LIMIT 5
"""
top5_df = run_query(query_top5)

# Removing 'Unknown' from our category list
top_5 = top5_df[top5_df['industry'] != 'Unknown']['industry'].tolist()
display(top_5)
# Out:
# ['Construction',
#  'Utilities and transportation',
#  'Mining and manufacturing',
#  'Wholesale trade',
#  'Fin. svs. and real est.']

# %%
# Pulling the year-by-year enrollment rate for all industries, excluding 'Unknown'
query = """
SELECT 
    year,
    row_label AS industry,
    ROUND(AVG(value_rounded), 1) AS enrollment_rate
FROM meps_ic
WHERE estimate LIKE '%Percent of employees enrolled%'
  AND row_group = 'Industry group'
  AND col_label = 'Total'
  AND year >= 2000
GROUP BY year, row_label
ORDER BY year, industry
"""
enrollment_trend = run_query(query)

# Filtering the dataset to include only the top 5 industries
enrollment_trend = enrollment_trend[enrollment_trend['industry'].isin(top_5)]
display(enrollment_trend.head())
# Out:
#    year                      industry  enrollment_rate
# 1  2000                  Construction             47.2
# 2  2000       Fin. svs. and real est.             45.3
# 3  2000      Mining and manufacturing             46.6
# 8  2000  Utilities and transportation             52.8
# 9  2000               Wholesale trade             47.6

# %%
#Plotting a multi-line time series chart to compare enrollment trends across industries
plt.figure(figsize=(12, 6))

colors = ['#003f5c', '#006770', '#008c54', '#7aa609', '#ffa600']

for i, industry in enumerate(top_5):
    data = enrollment_trend[enrollment_trend['industry'] == industry]
    plt.plot(data['year'], data['enrollment_rate'], marker='o', label=industry, color=colors[i])

# Adding a 60% reference line for comparison across industries
plt.axhline(y=60, color='gray', linestyle='--', label='60% line')
plt.title('Enrollment Rate Over Time: Top 5 Industries (2000–2024)')
plt.xlabel('Year')
plt.ylabel('Enrollment Rate (%)')
plt.xticks(range(2000, 2025, 4))
plt.legend(loc='upper right', bbox_to_anchor=(1, 0.95), fontsize=10)
plt.tight_layout()
plt.show()

# %% [markdown]
# **What I found:** Enrollment rates dropped around 2001, stayed flat between 30–40% for nearly two decades, then shot up after 2019, probably due to COVID. I was surprised the numbers never crossed 60%, so I looked into it. Turns out a lot of non-enrollees aren't actually uninsured; they're either on a spouse's plan or Medicaid. Cost seems to be the other big reason, especially for lower-wage workers. That would also explain why Agriculture and Construction sit at the bottom.

# %% [markdown]
# ## Key Takeaways
# - Premiums have risen consistently for nearly three decades with no meaningful plateaus, putting pressure on employers of all sizes.
# - Firm size matters less than expected. Smaller firms pay the highest premiums, but larger firms are not far behind, likely because they offer richer plans.
# - Industry and workforce composition are stronger predictors of both premium levels and enrollment rates than firm size alone.
# - Enrollment improved after 2019, but rates still sit under 60% in most industries, meaning cost remains a real barrier for many workers.
#
# **Bottom line:** It's pretty clear from the analysis that rising premiums are not a new problem. What's less obvious until you dig into it is how much industry and plan design shape the numbers, often more than firm size does. Benchmarking exists precisely because these patterns are easy to miss without the right context.
